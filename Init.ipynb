# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting xgboost==3.0.0
#   Downloading xgboost-3.0.0-py3-none-manylinux_2_28_x86_64.whl (253.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━ 253.9/253.9 MB 3.8 MB/s eta 0:00:00
# Collecting geocoder==1.38.1
#   Downloading geocoder-1.38.1-py2.py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 98.6/98.6 kB 17.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /root/venv/lib/python3.10/site-packages (from xgboost==3.0.0->-r ./requirements.txt (line 2)) (1.9.3)
# Collecting nvidia-nccl-cu12
#   Downloading nvidia_nccl_cu12-2.26.2.post1-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (291.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━ 291.7/291.7 MB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /root/venv/lib/python3.10/site-packages (from xgboost==3.0.0->-r ./requirements.txt (line 2)) (1.25.2)
# Requirement already satisfied: requests in /root/venv/lib/python3.10/site-packages (from geocoder==1.38.1->-r ./requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: click in /root/venv/lib/python3.10/site-packages (from geocoder==1.38.1->-r ./requirements.txt (line 3)) (8.1.8)
# Requirement already satisfied: six in /root/venv/lib/python3.10/site-packages (from geocoder==1.38.1->-r ./requirements.txt (line 3)) (1.17.0)
# Collecting ratelim
#   Downloading ratelim-0.1.6-py2.py3-none-any.whl (4.0 kB)
# Requirement already satisfied: future in /root/venv/lib/python3.10/site-packages (from geocoder==1.38.1->-r ./requirements.txt (line 3)) (1.0.0)
# Requirement already satisfied: decorator in /root/venv/lib/python3.10/site-packages (from ratelim->geocoder==1.38.1->-r ./requirements.txt (line 3)) (5.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.10/site-packages (from requests->geocoder==1.38.1->-r ./requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.10/site-packages (from requests->geocoder==1.38.1->-r ./requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.10/site-packages (from requests->geocoder==1.38.1->-r ./requirements.txt (line 3)) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.10/site-packages (from requests->geocoder==1.38.1->-r ./requirements.txt (line 3)) (3.10)
# Installing collected packages: ratelim, nvidia-nccl-cu12, xgboost, geocoder
# Successfully installed geocoder-1.38.1 nvidia-nccl-cu12-2.26.2.post1 ratelim-0.1.6 xgboost-3.0.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
